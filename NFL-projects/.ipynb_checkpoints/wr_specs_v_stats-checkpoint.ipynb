# %%
import pandas as pd

# %%
combine_stats = pd.read_csv('nfl_combine_since_2010.csv')
combine_stats
# Out:
#       Unnamed: 0             Player   Pos           School        College  \
# 0              1     Seyi Ajirotutu    WR     Fresno State  College Stats
# 1              2         Rahim Alem    DE              LSU  College Stats
# 2              3  Charles Alexander    DT              LSU  College Stats
# 3              4  Danario Alexander    WR         Missouri  College Stats
# 4              5         Nate Allen     S    South Florida  College Stats
# ...          ...                ...   ...              ...            ...
# 4736        4737        Luke Wypler     C         Ohio St.  College Stats
# 4737        4738        Bryce Young    QB          Alabama  College Stats
# 4738        4739        Byron Young    DT          Alabama  College Stats
# 4739        4740        Byron Young  EDGE        Tennessee  College Stats
# 4740        4741      Cameron Young    DT  Mississippi St.  College Stats
#
#         Ht     Wt  40yd  Vertical  Bench  Broad Jump  3Cone  Shuttle  \
# 0      6-3  204.0  4.60      36.0   14.0       115.0   7.22     4.39
# 1      6-3  251.0  4.75      30.5    NaN       106.0   7.54     4.80
# 2      6-4  300.0  5.40       NaN    NaN         NaN    NaN      NaN
# 3      6-5  215.0  4.62       NaN    NaN         NaN    NaN      NaN
# 4      6-0  207.0  4.50       NaN   16.0         NaN    NaN      NaN
# ...    ...    ...   ...       ...    ...         ...    ...      ...
# 4736   6-3  303.0  5.14      30.5    NaN       106.0   7.64     4.53
# 4737  5-10  204.0   NaN       NaN    NaN         NaN    NaN      NaN
# 4738   6-3  294.0   NaN      26.0   24.0       108.0   7.68      NaN
# 4739   6-2  250.0  4.43      38.0   22.0       132.0   7.19      NaN
# 4740   6-3  304.0  5.10       NaN    NaN         NaN    NaN      NaN
#
#                                Drafted (tm/rnd/yr)
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4     Philadelphia Eagles / 2nd / 37th pick / 2010
# ...                                            ...
# 4736    Cleveland Browns / 6th / 190th pick / 2023
# 4737     Carolina Panthers / 1st / 1st pick / 2023
# 4738    Las Vegas Raiders / 3rd / 70th pick / 2023
# 4739     Los Angeles Rams / 3rd / 77th pick / 2023
# 4740    Seattle Seahawks / 4th / 123rd pick / 2023
#
# [4741 rows x 14 columns]

# %%
wr_combine_stats = combine_stats[combine_stats['Pos'] == 'WR']
wr_combine_stats
# Out:
#       Unnamed: 0             Player Pos         School        College    Ht  \
# 0              1     Seyi Ajirotutu  WR   Fresno State  College Stats   6-3
# 3              4  Danario Alexander  WR       Missouri  College Stats   6-5
# 10            11       Alric Arnett  WR  West Virginia  College Stats   6-2
# 14            15      Brandon Banks  WR   Kansas State  College Stats   5-7
# 18            19         Chris Bell  WR  Norfolk State            NaN   6-2
# ...          ...                ...  ..            ...            ...   ...
# 4705        4706         Tre Tucker  WR     Cincinnati  College Stats   5-9
# 4719        4720  Parker Washington  WR       Penn St.  College Stats  5-10
# 4720        4721        Jalen Wayne  WR  South Alabama  College Stats   6-2
# 4725        4726   Dontayvion Wicks  WR       Virginia  College Stats   6-1
# 4729        4730     Michael Wilson  WR       Stanford  College Stats   6-2
#
#          Wt  40yd  Vertical  Bench  Broad Jump  3Cone  Shuttle  \
# 0     204.0  4.60      36.0   14.0       115.0   7.22     4.39
# 3     215.0  4.62       NaN    NaN         NaN    NaN      NaN
# 10    188.0  4.52      40.0    NaN       122.0   7.03     4.43
# 14    149.0  4.37      31.0    NaN       113.0   6.88     4.29
# 18    211.0  4.50      35.0   15.0       117.0   6.76     4.35
# ...     ...   ...       ...    ...         ...    ...      ...
# 4705  182.0  4.40      37.5    NaN       124.0    NaN      NaN
# 4719  204.0   NaN       NaN   16.0         NaN    NaN      NaN
# 4720  210.0  4.51      34.5    NaN       124.0    NaN      NaN
# 4725  206.0  4.62      39.0    NaN       130.0    NaN      NaN
# 4729  213.0  4.58      37.5   23.0       125.0    NaN     4.27
#
#                                  Drafted (tm/rnd/yr)
# 0                                                NaN
# 3                                                NaN
# 10                                               NaN
# 14                                               NaN
# 18                                               NaN
# ...                                              ...
# 4705     Las Vegas Raiders / 3rd / 100th pick / 2023
# 4719  Jacksonville Jaguars / 6th / 185th pick / 2023
# 4720                                             NaN
# 4725     Green Bay Packers / 5th / 159th pick / 2023
# 4729      Arizona Cardinals / 3rd / 94th pick / 2023
#
# [670 rows x 14 columns]

# %%
receiving_stats_2023 = pd.read_csv('receivers_2023.csv')
wrs_2023 = receiving_stats_2023[receiving_stats_2023['Pos'] == 'WR']
wrs_2023['Player'] = wrs_2023['Player'].map(lambda x: x.rstrip('+').rstrip('*'))
wrs_2023
# Out:
# /var/folders/7z/7xs3z6hn5156943w6pqkzkzw0000gn/T/ipykernel_24563/3930417782.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wrs_2023['Player'] = wrs_2023['Player'].map(lambda x: x.rstrip('+').rstrip('*'))
#       Rk               Player   Tm  Age Pos   G  GS  Tgt  Rec   Yds  ...  YAC  \
# 0      1          CeeDee Lamb  DAL   24  WR  17  17  181  135  1749  ...  680
# 1      2          Tyreek Hill  MIA   29  WR  16  16  171  119  1799  ...  652
# 2      3    Amon-Ra St. Brown  DET   24  WR  16  16  164  119  1515  ...  668
# 4      5  Michael Pittman Jr.  IND   26  WR  16  15  156  109  1152  ...  513
# 5      6         Keenan Allen  LAC   31  WR  13  13  150  108  1243  ...  396
# ..   ...                  ...  ...  ...  ..  ..  ..  ...  ...   ...  ...  ...
# 471  472     Shedrick Jackson  CIN   24  WR   5   0    1    0     0  ...    0
# 475  476         James Proche  CLE   27  WR  10   1    5    0     0  ...    0
# 476  477        Amari Rodgers  IND   24  WR   3   0    2    0     0  ...    0
# 478  479         Trent Taylor  CHI   29  WR  17   0    2    0     0  ...    0
# 481  482       Juwann Winfree  IND   27  WR   8   1    1    0     0  ...    0
#
#      YAC/R  ADOT  BrkTkl  Rec/Br  Drop  Drop%  Int    Rat  Player-additional
# 0      5.0   9.5      11    12.3     6    3.3    1  124.3           LambCe00
# 1      5.5  10.8      12     9.9    12    7.0    5  117.1           HillTy00
# 2      5.6   7.8      10    11.9     8    4.9    3  113.7           StxxAm00
# 4      4.7   7.9       3    36.3     3    1.9    6   83.6           PittMi01
# 5      3.7   9.6       5    21.6     5    3.3    2  106.6           AlleKe00
# ..     ...   ...     ...     ...   ...    ...  ...    ...                ...
# 471    NaN  30.0       0     NaN     0    0.0    0   39.6           JackSh01
# 475    NaN  17.2       0     NaN     0    0.0    1    0.0           ProcJa00
# 476    NaN  15.0       0     NaN     1   50.0    0   39.6           RodgAm00
# 478    NaN   0.0       0     NaN     0    0.0    0   39.6           TaylTr02
# 481    NaN  26.0       0     NaN     0    0.0    0   39.6           WinfJu00
#
# [207 rows x 24 columns]

# %%
wrs_2023 = pd.merge(combine_stats, wrs_2023, how='inner', on=['Player'])
wrs_2023 = wrs_2023.sort_values(by=['Yds'], ascending=False)
wrs_2023
# Out:
#      Unnamed: 0             Player Pos_x          School        College    Ht  \
# 78         3487        CeeDee Lamb    WR        Oklahoma  College Stats   6-2
# 87         3682  Amon-Ra St. Brown    WR             USC  College Stats  5-11
# 144        4629         Puka Nacua    WR             BYU  College Stats   6-2
# 52         3002         A.J. Brown    WR     Mississippi  College Stats   6-0
# 46         2832         D.J. Moore    WR        Maryland  College Stats   6-0
# ..          ...                ...   ...             ...            ...   ...
# 90         3750   D'Wayne Eskridge    WR  West. Michigan  College Stats   5-8
# 19         1732    Phillip Dorsett    WR      Miami (FL)  College Stats  5-10
# 96         3975      Amari Rodgers    WR         Clemson  College Stats   5-9
# 81         3552       James Proche    WR             SMU  College Stats  5-11
# 106        4192      Erik Ezukanma    WR      Texas Tech  College Stats   6-2
#
#         Wt  40yd  Vertical  Bench  ...  YAC  YAC/R  ADOT BrkTkl  Rec/Br Drop  \
# 78   198.0  4.50      34.5   11.0  ...  680    5.0   9.5     11    12.3    6
# 87   197.0  4.51      38.5   20.0  ...  668    5.6   7.8     10    11.9    8
# 144  201.0   NaN       NaN    NaN  ...  632    6.0   9.1      7    15.0   13
# 52   226.0  4.49      36.5   19.0  ...  473    4.5  11.7      9    11.8    7
# 46   210.0  4.42      39.5   15.0  ...  539    5.6  10.9      9    10.7    4
# ..     ...   ...       ...    ...  ...  ...    ...   ...    ...     ...  ...
# 90   190.0  4.38      35.0    NaN  ...    0    NaN  17.0      0     NaN    0
# 19   185.0  4.33      37.0   13.0  ...    0    NaN  26.0      0     NaN    0
# 96   212.0  4.52      33.0   19.0  ...    0    NaN  15.0      0     NaN    1
# 81   201.0   NaN      34.5   20.0  ...    0    NaN  17.2      0     NaN    0
# 106  209.0   NaN      36.5    NaN  ...    0    NaN   8.0      0     NaN    0
#
#      Drop% Int    Rat  Player-additional
# 78     3.3   1  124.3           LambCe00
# 87     4.9   3  113.7           StxxAm00
# 144    8.1   3  100.2           NacuPu00
# 52     4.4   4  100.6           BrowAJ00
# 46     2.9   3  113.1           MoorD.00
# ..     ...  ..    ...                ...
# 90     0.0   0   39.6           EskrDW00
# 19     0.0   0   39.6           DorsPh00
# 96    50.0   0   39.6           RodgAm00
# 81     0.0   1    0.0           ProcJa00
# 106    0.0   0   39.6           EzukEr00
#
# [156 rows x 37 columns]

# %%
forty_yd_wrs = wrs_2023[~wrs_2023['40yd'].isna()][~wrs_2023['Ht'].isna()][~wrs_2023['Wt'].isna()]
forty_yd_wrs
# Out:
# /var/folders/7z/7xs3z6hn5156943w6pqkzkzw0000gn/T/ipykernel_24563/258748129.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   forty_yd_wrs = wrs_2023[~wrs_2023['40yd'].isna()][~wrs_2023['Ht'].isna()][~wrs_2023['Wt'].isna()]
# /var/folders/7z/7xs3z6hn5156943w6pqkzkzw0000gn/T/ipykernel_24563/258748129.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   forty_yd_wrs = wrs_2023[~wrs_2023['40yd'].isna()][~wrs_2023['Ht'].isna()][~wrs_2023['Wt'].isna()]
#      Unnamed: 0             Player Pos_x          School        College    Ht  \
# 78         3487        CeeDee Lamb    WR        Oklahoma  College Stats   6-2
# 87         3682  Amon-Ra St. Brown    WR             USC  College Stats  5-11
# 52         3002         A.J. Brown    WR     Mississippi  College Stats   6-0
# 46         2832         D.J. Moore    WR        Maryland  College Stats   6-0
# 66         3302      Brandon Aiyuk    WR   Arizona State  College Stats   6-0
# ..          ...                ...   ...             ...            ...   ...
# 134        4516      Antoine Green    WR  North Carolina  College Stats   6-2
# 40         2582       Trent Taylor    WR  Louisiana Tech  College Stats   5-8
# 90         3750   D'Wayne Eskridge    WR  West. Michigan  College Stats   5-8
# 19         1732    Phillip Dorsett    WR      Miami (FL)  College Stats  5-10
# 96         3975      Amari Rodgers    WR         Clemson  College Stats   5-9
#
#         Wt  40yd  Vertical  Bench  ...  YAC  YAC/R  ADOT BrkTkl  Rec/Br Drop  \
# 78   198.0  4.50      34.5   11.0  ...  680    5.0   9.5     11    12.3    6
# 87   197.0  4.51      38.5   20.0  ...  668    5.6   7.8     10    11.9    8
# 52   226.0  4.49      36.5   19.0  ...  473    4.5  11.7      9    11.8    7
# 46   210.0  4.42      39.5   15.0  ...  539    5.6  10.9      9    10.7    4
# 66   205.0  4.50      40.0   11.0  ...  382    5.1  13.8      2    37.5    2
# ..     ...   ...       ...    ...  ...  ...    ...   ...    ...     ...  ...
# 134  199.0  4.47      33.5    NaN  ...    1    1.0   5.5      0     NaN    0
# 40   181.0  4.63      33.0   13.0  ...    0    NaN   0.0      0     NaN    0
# 90   190.0  4.38      35.0    NaN  ...    0    NaN  17.0      0     NaN    0
# 19   185.0  4.33      37.0   13.0  ...    0    NaN  26.0      0     NaN    0
# 96   212.0  4.52      33.0   19.0  ...    0    NaN  15.0      0     NaN    1
#
#      Drop% Int    Rat  Player-additional
# 78     3.3   1  124.3           LambCe00
# 87     4.9   3  113.7           StxxAm00
# 52     4.4   4  100.6           BrowAJ00
# 46     2.9   3  113.1           MoorD.00
# 66     1.9   3  124.0           AiyuBr00
# ..     ...  ..    ...                ...
# 134    0.0   0   56.2           GreeAn00
# 40     0.0   0   39.6           TaylTr02
# 90     0.0   0   39.6           EskrDW00
# 19     0.0   0   39.6           DorsPh00
# 96    50.0   0   39.6           RodgAm00
#
# [133 rows x 37 columns]

# %%
def parse_ht(ht):
    # format: X-XX
    ht_ = ht.split("-")
    ft_, in_ = float(ht_[0]), float(ht_[1])
    return (12*ft_) + in_

# %%
forty_yd_wrs['Ht'] = forty_yd_wrs['Ht'].apply(lambda x:parse_ht(x))
forty_yd_wrs
# Out:
#      Unnamed: 0             Player Pos_x          School        College    Ht  \
# 78         3487        CeeDee Lamb    WR        Oklahoma  College Stats  74.0
# 87         3682  Amon-Ra St. Brown    WR             USC  College Stats  71.0
# 52         3002         A.J. Brown    WR     Mississippi  College Stats  72.0
# 46         2832         D.J. Moore    WR        Maryland  College Stats  72.0
# 66         3302      Brandon Aiyuk    WR   Arizona State  College Stats  72.0
# ..          ...                ...   ...             ...            ...   ...
# 134        4516      Antoine Green    WR  North Carolina  College Stats  74.0
# 40         2582       Trent Taylor    WR  Louisiana Tech  College Stats  68.0
# 90         3750   D'Wayne Eskridge    WR  West. Michigan  College Stats  68.0
# 19         1732    Phillip Dorsett    WR      Miami (FL)  College Stats  70.0
# 96         3975      Amari Rodgers    WR         Clemson  College Stats  69.0
#
#         Wt  40yd  Vertical  Bench  ...  YAC  YAC/R  ADOT BrkTkl  Rec/Br Drop  \
# 78   198.0  4.50      34.5   11.0  ...  680    5.0   9.5     11    12.3    6
# 87   197.0  4.51      38.5   20.0  ...  668    5.6   7.8     10    11.9    8
# 52   226.0  4.49      36.5   19.0  ...  473    4.5  11.7      9    11.8    7
# 46   210.0  4.42      39.5   15.0  ...  539    5.6  10.9      9    10.7    4
# 66   205.0  4.50      40.0   11.0  ...  382    5.1  13.8      2    37.5    2
# ..     ...   ...       ...    ...  ...  ...    ...   ...    ...     ...  ...
# 134  199.0  4.47      33.5    NaN  ...    1    1.0   5.5      0     NaN    0
# 40   181.0  4.63      33.0   13.0  ...    0    NaN   0.0      0     NaN    0
# 90   190.0  4.38      35.0    NaN  ...    0    NaN  17.0      0     NaN    0
# 19   185.0  4.33      37.0   13.0  ...    0    NaN  26.0      0     NaN    0
# 96   212.0  4.52      33.0   19.0  ...    0    NaN  15.0      0     NaN    1
#
#      Drop% Int    Rat  Player-additional
# 78     3.3   1  124.3           LambCe00
# 87     4.9   3  113.7           StxxAm00
# 52     4.4   4  100.6           BrowAJ00
# 46     2.9   3  113.1           MoorD.00
# 66     1.9   3  124.0           AiyuBr00
# ..     ...  ..    ...                ...
# 134    0.0   0   56.2           GreeAn00
# 40     0.0   0   39.6           TaylTr02
# 90     0.0   0   39.6           EskrDW00
# 19     0.0   0   39.6           DorsPh00
# 96    50.0   0   39.6           RodgAm00
#
# [133 rows x 37 columns]

# %%
forty_yd_wrs['BMI'] = 703 * (forty_yd_wrs['Wt'] / (forty_yd_wrs['Ht']*forty_yd_wrs['Ht']))
forty_yd_wrs
# Out:
#      Unnamed: 0             Player Pos_x          School        College    Ht  \
# 78         3487        CeeDee Lamb    WR        Oklahoma  College Stats  74.0
# 87         3682  Amon-Ra St. Brown    WR             USC  College Stats  71.0
# 52         3002         A.J. Brown    WR     Mississippi  College Stats  72.0
# 46         2832         D.J. Moore    WR        Maryland  College Stats  72.0
# 66         3302      Brandon Aiyuk    WR   Arizona State  College Stats  72.0
# ..          ...                ...   ...             ...            ...   ...
# 134        4516      Antoine Green    WR  North Carolina  College Stats  74.0
# 40         2582       Trent Taylor    WR  Louisiana Tech  College Stats  68.0
# 90         3750   D'Wayne Eskridge    WR  West. Michigan  College Stats  68.0
# 19         1732    Phillip Dorsett    WR      Miami (FL)  College Stats  70.0
# 96         3975      Amari Rodgers    WR         Clemson  College Stats  69.0
#
#         Wt  40yd  Vertical  Bench  ...  YAC/R  ADOT  BrkTkl Rec/Br  Drop  \
# 78   198.0  4.50      34.5   11.0  ...    5.0   9.5      11   12.3     6
# 87   197.0  4.51      38.5   20.0  ...    5.6   7.8      10   11.9     8
# 52   226.0  4.49      36.5   19.0  ...    4.5  11.7       9   11.8     7
# 46   210.0  4.42      39.5   15.0  ...    5.6  10.9       9   10.7     4
# 66   205.0  4.50      40.0   11.0  ...    5.1  13.8       2   37.5     2
# ..     ...   ...       ...    ...  ...    ...   ...     ...    ...   ...
# 134  199.0  4.47      33.5    NaN  ...    1.0   5.5       0    NaN     0
# 40   181.0  4.63      33.0   13.0  ...    NaN   0.0       0    NaN     0
# 90   190.0  4.38      35.0    NaN  ...    NaN  17.0       0    NaN     0
# 19   185.0  4.33      37.0   13.0  ...    NaN  26.0       0    NaN     0
# 96   212.0  4.52      33.0   19.0  ...    NaN  15.0       0    NaN     1
#
#     Drop%  Int    Rat  Player-additional        BMI
# 78    3.3    1  124.3           LambCe00  25.418919
# 87    4.9    3  113.7           StxxAm00  27.472922
# 52    4.4    4  100.6           BrowAJ00  30.647762
# 46    2.9    3  113.1           MoorD.00  28.478009
# 66    1.9    3  124.0           AiyuBr00  27.799961
# ..    ...  ...    ...                ...        ...
# 134   0.0    0   56.2           GreeAn00  25.547297
# 40    0.0    0   39.6           TaylTr02  27.517950
# 90    0.0    0   39.6           EskrDW00  28.886246
# 19    0.0    0   39.6           DorsPh00  26.541837
# 96   50.0    0   39.6           RodgAm00  31.303508
#
# [133 rows x 38 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.figure(figsize=(12,8))
plt.scatter(forty_yd_wrs['BMI'], forty_yd_wrs['40yd'])

matplotlib.rcParams['font.size'] = 7
for i, txt in enumerate(forty_yd_wrs['Player']):
    plt.annotate(txt, (forty_yd_wrs['BMI'].iloc[i], forty_yd_wrs['40yd'].iloc[i]))

plt.xlabel('BMI', fontdict={'family': 'sans-serif', 'weight': 'normal', 'size': 10})
plt.ylabel('40yd', fontdict={'family': 'sans-serif', 'weight': 'normal', 'size': 10})
plt.title('Comparing Size v. Speed in NFL WRs, 2023 Season', fontdict={'family': 'sans-serif', 'weight': 'normal', 'size': 12})
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.scatter(forty_yd_wrs['40yd'], forty_yd_wrs['YAC']/forty_yd_wrs['Yds'])

matplotlib.rcParams['font.size'] = 7
for i, txt in enumerate(forty_yd_wrs['Player']):
    plt.annotate(txt, (forty_yd_wrs['BMI'].iloc[i], forty_yd_wrs['40yd'].iloc[i]))

plt.xlabel('BMI', fontdict={'family': 'sans-serif', 'weight': 'normal', 'size': 10})
plt.ylabel('40yd', fontdict={'family': 'sans-serif', 'weight': 'normal', 'size': 10})
plt.title('Comparing Size v. Speed in NFL WRs, 2023 Season', fontdict={'family': 'sans-serif', 'weight': 'normal', 'size': 12})
plt.show()
